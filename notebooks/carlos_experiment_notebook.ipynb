# %% [markdown]
# # Carlos experiment notebook
#
# This notebook represents the original experimental model. The production project moves the same idea into modular code, Airflow DAGs, MLflow tracking, validation, monitoring, and CI/CD.

# %%
from src.data.generate_synthetic_data import generate_synthetic_data
from src.features.build_features import build_training_dataset

df = generate_synthetic_data('2024-01-01', '2024-03-01')
features = build_training_dataset(df)
features.head()
